# %%
from utils import *
from dataset import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
set_seed(42)

classes = ['wheat','paco']
# iou_thresholds = np.arange(.5, .75+1e-10, .05)
da = DetAux(classes)

# %%
bs = 2
nw = 0
root = 'C:/Users/alberto/Downloads/global-wheat-detection'

train_dataset = WheatDataset(root=root, split='train')

train_data_loader = torch.utils.data.DataLoader(
    train_dataset, 
    batch_size=bs, 
    shuffle=True, 
    num_workers=nw, 
    collate_fn=train_dataset.collate_fn
)

test_dataset = WheatDataset(root=root, split='test')

test_data_loader = torch.utils.data.DataLoader(
    test_dataset, 
    batch_size=bs, 
    shuffle=False, 
    num_workers=nw, 
    collate_fn=test_dataset.collate_fn
)

# %%
da.show_batch_of_images(train_data_loader)
